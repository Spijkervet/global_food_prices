# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
# %matplotlib inline

# get database as panda dataframe
df = pd.read_csv('WFPVAM_FoodPrices_version1.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-ee685654004e> in <module>()
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3
#       4 from matplotlib import pyplot as plt
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# for a more intuitive access to the database
COUNTRY = 'adm0_name'
REGION = 'adm1_name'
CITY = 'mkt_name'
PROD = 'cm_name'
CURR = 'cur_name'
SELLER = 'pt_name'
UNIT = 'um_name'
MONTH = 'mp_month'
YEAR = 'mp_year'
DATE = 'date'
PRICE = 'mp_price'
SOURCE = 'mp_commoditysource'

# gets all products as keys with according units as values #
dict = {}
for (product, unit), df_group in df.groupby(["cm_name", "um_name"]):
    if not product in dict:
        dict[product] = [unit]
    else:
        dict[product].append(unit)

# comprehends created dict to include only products with inconsistent unit measures #
dict2 = {key: value for key, value in dict.items() if len(value) > 1}

# number of products with inconsistent (more than one) unit measures
print(len(dict2))


# returns all unit measures used in database
print(df.eval(UNIT).unique())
# Out:
# 96
# ['KG' 'Day' 'Unit' 'L' 'USD/LCU' '11.5 KG' 'Pound' 'Cuartilla' '90 KG' 'MT'
#  'Libra' 'Gallon' '380 G' 'Month' '85 G' '500 ML' 'Course' '45 KG' 'Head'
#  '100 KG' '500 G' '50 KG' '91 KG' 'Bunch' '100 Tubers' '650 G' '750 ML'
#  '115 G' 'Marmite' '350 G' '385 G' '1.8 KG' '2 KG' '400 G' '10 pcs' '150 G'
#  '5 KG' '30 pcs' '5 L' '160 G' '200 G' '12.5 KG' 'Loaf' 'Dozen' 'Sack'
#  '1.5 KG' '185 G' '10 KG' 'Packet' '750 G' '1.5 L' '12 KG' '18 KG' '25 KG'
#  '3 L' 'Cubic meter' '3 KG' '3.5 KG' '168 G']

# %%
# assuming:
# 1 Libra = 0.329 kg
# 1 MT (Metric Ton) = 1000 KG
# 1 L Palm Oil = 0.91298 KG
UNIT_PRICE_CONVERTER = {'1.5 KG': (1.5, 'KG'), '5 KG': (5.0, 'KG'), '1.8 KG': (1.8, 'KG'), 
                        '2 KG': (2.0, 'KG'), '12.5 KG': (12.5, 'KG'), '10 KG': (10.0, 'KG'),
                        '60 KG': (60.0, 'KG'), '18 KG': (18.0, 'KG'), '25 KG': (25.0, 'KG'),
                        '3 KG': (3.0, 'KG'), '3.5 KG': (3.5, 'KG'), '12 KG': (12.0, 'KG'),
                        '500 G': (0.5, 'KG'), '125 G': (0.125, 'KG'), '90 KG': (90.0, 'KG'), 
                        'Pound': (0.45359237, 'KG'), '380 G': (0.380, 'KG'), '85 G': (0.085, 'KG'),
                        '45 KG': (45.0, 'KG'), '100 KG': (100.0, 'KG'), '50 KG': (50.0, 'KG'), 
                        '91 KG': (91.0, 'KG'), '650 G': (0.650, 'KG'), '115 G': (0.115, 'KG'),
                        '350 G': (0.350, 'KG'), '385 G': (0.385, 'KG'), '11.5 KG': (11.5, 'KG'),
                        '400 G': (0.400, 'KG'), '150 G': (0.150, 'KG'), '160 G': (0.160, 'KG'), 
                        '200 G': (0.200, 'KG'), '185 G': (0.185, 'KG'), '750 G': (0.750, 'KG'),
                        '168 G': (0.168, 'KG'), 'Libra': (0.329, 'KG'), 'MT': (1000.0, 'KG'),
                        'Gallon': (3.78541178, 'L'), '500 ML': (0.500, 'L'), '750 ML': (0.750, 'L'),
                        '1.5 L': (1.5, 'L'), '3 L': (3.0, 'L'), 'Cubic Meter': (1000.0, 'L'),
                        '5 L': (5.0, 'L'), 'L': (1, 'L'), 
                        '10 pcs': (10.0, 'pcs'), '30 pcs': (30.0, 'pcs'), 'Dozen': (12.0, "pcs")}
                        
                        

CONV_PRICE = 0
CONV_UNIT = 1



def get_values_column(df, column_name, value):
    """
    df = dataset
    column_name = kolom waarin je wil zoeken
    value = waarde die je uit de kolom wil.

    return nieuwe dataset met alle rijen die alleen de value in de gegeven kolommen bevatten.
    """
    return df.loc[df[column_name] == value]

def norm_price_unit(row, Col):
    """

    """
    if Col:
        try:
            return UNIT_PRICE_CONVERTER[row.get(UNIT)][Col]
        except:
            return row.get(UNIT)
    else:
        try:
            return row.get(PRICE) / UNIT_PRICE_CONVERTER[row.get(UNIT)][Col]
        except:
            return row.get(PRICE)

def norm_unit(df):
    
    df[PRICE] = df.apply(lambda row: norm_price_unit(row, CONV_PRICE), axis = 1)
    df[UNIT] = df.apply(lambda row: norm_price_unit(row, CONV_UNIT), axis = 1)


# norm_unit(df)


# faster with merger
df_unit = pd.DataFrame.from_dict(UNIT_PRICE_CONVERTER, orient = 'index')
df_unit.columns = ['factor', 'unit_new']
df_unit.head()
df2 = pd.DataFrame.merge(df,
                        df_unit,
                        left_on = UNIT,
                        how = 'left',
                        right_index = True)

df2.drop(UNIT, axis=1, inplace = True)
df2=df2.rename(columns = {'unit_new': UNIT})

df2[PRICE] = df2[PRICE].multiply(df2['factor'], axis='index', fill_value = 1)
print(df2)


# dict = {}
# for (product, unit), df_group in df.groupby(["cm_name", "um_name"]):
#     if not product in dict:
#         dict[product] = [unit]
#     else:
#         dict[product].append(unit)

# dict2 = {key: value for (key, value)
#          in dict.items() if len(value) > 1}

# print(len(dict2))
# print(df.eval(UNIT).unique())
# Out:
#           adm0_name  mkt_name               cm_name cur_name pt_name  \
# 0       Afghanistan  Fayzabad                 Bread      AFN  Retail
# 1       Afghanistan  Fayzabad                 Bread      AFN  Retail
# 2       Afghanistan  Fayzabad                 Bread      AFN  Retail
# 3       Afghanistan  Fayzabad                 Bread      AFN  Retail
# 4       Afghanistan  Fayzabad                 Bread      AFN  Retail
# 5       Afghanistan  Fayzabad                 Bread      AFN  Retail
# 6       Afghanistan  Fayzabad                 Bread      AFN  Retail
# 7       Afghanistan  Fayzabad                 Bread      AFN  Retail
# 8       Afghanistan  Fayzabad                 Bread      AFN  Retail
# 9       Afghanistan  Fayzabad                 Bread      AFN  Retail
# 10      Afghanistan  Fayzabad                 Bread      AFN  Retail
# 11      Afghanistan  Fayzabad                 Bread      AFN  Retail
# 12      Afghanistan  Fayzabad                 Bread      AFN  Retail
# 13      Afghanistan  Fayzabad                 Bread      AFN  Retail
# 14      Afghanistan  Fayzabad                 Bread      AFN  Retail
# 15      Afghanistan  Fayzabad                 Bread      AFN  Retail
# 16      Afghanistan  Fayzabad                 Bread      AFN  Retail
# 17      Afghanistan  Fayzabad                 Bread      AFN  Retail
# 18      Afghanistan  Fayzabad                 Bread      AFN  Retail
# 19      Afghanistan  Fayzabad                 Bread      AFN  Retail
# 20      Afghanistan  Fayzabad                 Bread      AFN  Retail
# 21      Afghanistan  Fayzabad                 Bread      AFN  Retail
# 22      Afghanistan  Fayzabad                 Bread      AFN  Retail
# 23      Afghanistan  Fayzabad                 Bread      AFN  Retail
# 24      Afghanistan  Fayzabad                 Bread      AFN  Retail
# 25      Afghanistan  Fayzabad                 Bread      AFN  Retail
# 26      Afghanistan  Fayzabad                 Bread      AFN  Retail
# 27      Afghanistan  Fayzabad                 Bread      AFN  Retail
# 28      Afghanistan  Fayzabad                 Bread      AFN  Retail
# 29      Afghanistan  Fayzabad                 Bread      AFN  Retail
# ...             ...       ...                   ...      ...     ...
# 746499  South Sudan     Torit       Oil (vegetable)      SSP  Retail
# 746500  South Sudan     Torit       Oil (vegetable)      SSP  Retail
# 746501  South Sudan     Torit       Oil (vegetable)      SSP  Retail
# 746502  South Sudan     Torit       Oil (vegetable)      SSP  Retail
# 746503  South Sudan     Torit       Oil (vegetable)      SSP  Retail
# 746504  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
# 746505  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
# 746506  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
# 746507  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
# 746508  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
# 746509  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
# 746510  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
# 746511  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
# 746512  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
# 746513  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
# 746514  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
# 746515  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
# 746516  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
# 746517  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
# 746518  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
# 746519  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
# 746520  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
# 746521  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
# 746522  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
# 746523  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
# 746524  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
# 746525  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
# 746526  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
# 746527  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
# 746528  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail
#
#         mp_price     date  factor um_name
# 0        50.0000   2014-1     NaN     NaN
# 1        50.0000   2014-2     NaN     NaN
# 2        50.0000   2014-3     NaN     NaN
# 3        50.0000   2014-4     NaN     NaN
# 4        50.0000   2014-5     NaN     NaN
# 5        50.0000   2014-6     NaN     NaN
# 6        50.0000   2014-7     NaN     NaN
# 7        50.0000   2014-8     NaN     NaN
# 8        50.0000   2014-9     NaN     NaN
# 9        50.0000  2014-10     NaN     NaN
# 10       50.0000  2014-11     NaN     NaN
# 11       50.0000  2014-12     NaN     NaN
# 12       50.0000   2015-1     NaN     NaN
# 13       50.0000   2015-2     NaN     NaN
# 14       50.0000   2015-3     NaN     NaN
# 15       50.0000   2015-6     NaN     NaN
# 16       50.0000   2015-7     NaN     NaN
# 17       50.0000   2015-8     NaN     NaN
# 18       50.0000   2015-9     NaN     NaN
# 19       56.2500  2015-10     NaN     NaN
# 20       65.2500  2015-11     NaN     NaN
# 21       55.5000  2015-12     NaN     NaN
# 22       55.5000   2016-1     NaN     NaN
# 23       55.5000   2016-2     NaN     NaN
# 24       55.5000   2016-3     NaN     NaN
# 25       50.0000   2016-4     NaN     NaN
# 26       50.0000   2016-5     NaN     NaN
# 27       50.0000   2016-6     NaN     NaN
# 28       50.0000   2016-7     NaN     NaN
# 29       50.0000   2016-8     NaN     NaN
# ...          ...      ...     ...     ...
# 746499  250.0000   2017-5     1.0       L
# 746500  244.0000   2017-6     1.0       L
# 746501  240.0000   2017-7     1.0       L
# 746502  240.0000   2017-8     1.0       L
# 746503  235.0000  2017-10     1.0       L
# 746504    9.5000   2014-8     NaN     NaN
# 746505    9.0000   2014-9     NaN     NaN
# 746506    9.0000  2014-10     NaN     NaN
# 746507    8.3333  2014-11     NaN     NaN
# 746508   10.5000  2014-12     NaN     NaN
# 746509    8.0000   2015-1     NaN     NaN
# 746510    8.0000   2015-2     NaN     NaN
# 746511    7.0000   2015-3     NaN     NaN
# 746512   10.0000   2015-4     NaN     NaN
# 746513   41.0000   2016-1     NaN     NaN
# 746514   57.7500   2016-3     NaN     NaN
# 746515   37.7500   2016-4     NaN     NaN
# 746516   72.0000   2016-5     NaN     NaN
# 746517  100.0000   2016-7     NaN     NaN
# 746518  120.0000   2016-8     NaN     NaN
# 746519   73.5000   2016-9     NaN     NaN
# 746520  110.0000  2016-10     NaN     NaN
# 746521  132.5000  2016-11     NaN     NaN
# 746522  151.2500  2016-12     NaN     NaN
# 746523  200.0000   2017-2     NaN     NaN
# 746524  236.0000   2017-3     NaN     NaN
# 746525  250.0000   2017-6     NaN     NaN
# 746526  308.0000   2017-7     NaN     NaN
# 746527  343.0000   2017-8     NaN     NaN
# 746528  283.0000  2017-10     NaN     NaN
#
# [746529 rows x 9 columns]

# %%
# get products with multiple unit measures in one city
A = df.groupby([CITY, PROD])
print({len(tmp_df.eval(UNIT).unique()) for _, tmp_df in A})
[(group,tmp_df.eval(UNIT).unique()) for group, tmp_df in A if len(tmp_df.eval(UNIT).unique()) > 1]
# Out:
# {1, 2, 3}
# [(('Banjul', 'Coffee (instant)'), array(['KG', 'Unit'], dtype=object)),
#  (('Basse Santa su', 'Coffee (instant)'), array(['KG', 'Unit'], dtype=object)),
#  (('Biu', 'Oil (palm)'), array(['KG', 'L'], dtype=object)),
#  (('Brikama', 'Coffee (instant)'), array(['KG', 'Unit'], dtype=object)),
#  (('Damaturu', 'Oil (palm)'), array(['KG', 'L'], dtype=object)),
#  (('Gaalkacyo', 'Fuel (diesel)'), array(['KG', 'L'], dtype=object)),
#  (('Garowe', 'Fuel (diesel)'), array(['KG', 'L'], dtype=object)),
#  (('Medellin', 'Milk (pasteurized)'), array(['L', 'KG'], dtype=object)),
#  (('Mubi', 'Oil (palm)'), array(['KG', 'L'], dtype=object)),
#  (('National Average', 'Eggs'), array(['KG', 'Unit', 'pcs'], dtype=object)),
#  (('National Average', 'Oil (olive)'), array(['KG', 'L'], dtype=object)),
#  (('National Average', 'Oil (sunflower)'), array(['KG', 'L'], dtype=object)),
#  (('Serrekunda', 'Coffee (instant)'), array(['KG', 'Unit'], dtype=object)),
#  (('Soma', 'Coffee (instant)'), array(['KG', 'Unit'], dtype=object))]

# %%
is_eggs = df[PROD] == 'Eggs'
print(df[is_eggs][UNIT].value_counts())

is_coffee = df[PROD] == 'Coffee (instant)'
print(df[is_coffee][UNIT].value_counts())

is_oil = df[PROD] == 'Oil (palm)'
print(df[is_oil][UNIT].value_counts())
# Out:
# Unit    5177
# pcs     3835
# KG       749
# Name: um_name, dtype: int64
# Unit    155
# KG      132
# Name: um_name, dtype: int64
# L     7174
# KG    2199
# Name: um_name, dtype: int64

# %%
# assuming the volume to weight conversions from http://www.endmemo.com/cconvert/kgl.php
# 1 L Palm Oil = 0.913 KG
# 1 L Diesel = 0.851 KG
# 1 L milk = 1.033 KG
# 1 L olive oil = 1.096 KG
# 1 L sunflower oil = 0.920 KG


# {product: (new unit, old unit, conversion), etc.}
UNIT_PROD_PRICE_CONVERTER = {"Oil (palm)": ('KG', 'L', 0.913), "Fuel (diesel)": ('KG', 'L', 0.851),
                            "Milk (pasteurized)": ('KG', 'L', 1.033), "Oil (olive)": ('KG', 'L', 1.096),
                            "Oil (sunflower)": ('KG', 'L', 0.920)}
for product, (unit_N, unit_O, conversion) in UNIT_PROD_PRICE_CONVERTER.items():    
    price_new = lambda x: x * (1 / conversion)
    
    # CREATES MASK
    df_product = df[PROD] == product
    df_unit_O = df[UNIT] == unit_O

    df.loc[df_product & df_unit_O, PRICE] = df[df_product & df_unit_O][PRICE].apply(price_new)
    df.loc[df_product & df_unit_O, UNIT] = unit

    
is_diesel = df[PROD] == 'Fuel (diesel)'
print(df[is_diesel][UNIT].value_counts())
# Out:
# KG    9567
# Name: um_name, dtype: int64

# %%
# get products with multiple unit measures in one city
A = df.groupby([CITY, PROD])
print({len(tmp_df.eval(UNIT).unique()) for _, tmp_df in A})
[(group,tmp_df.eval(UNIT).unique()) for group, tmp_df in A if len(tmp_df.eval(UNIT).unique()) > 1]
# Out:
# {1, 2, 3}
# [(('Banjul', 'Coffee (instant)'), array(['KG', 'Unit'], dtype=object)),
#  (('Basse Santa su', 'Coffee (instant)'), array(['KG', 'Unit'], dtype=object)),
#  (('Brikama', 'Coffee (instant)'), array(['KG', 'Unit'], dtype=object)),
#  (('National Average', 'Eggs'), array(['KG', 'Unit', 'pcs'], dtype=object)),
#  (('Serrekunda', 'Coffee (instant)'), array(['KG', 'Unit'], dtype=object)),
#  (('Soma', 'Coffee (instant)'), array(['KG', 'Unit'], dtype=object))]

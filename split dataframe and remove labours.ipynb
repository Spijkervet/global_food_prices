# %%
#/usr/bin/python3
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt


COUNTRY = 'adm0_name'
REGION = 'adm1_name'
CITY = 'mkt_name'
PROD = 'cm_name'
CURR = 'cur_name'
SELLER = 'pt_name'
UNIT = 'um_name'
MONTH = 'mp_month'
YEAR = 'mp_year'
DATE = 'date'
PRICE = 'mp_price'
SOURCE = 'mp_commoditysource'

# %%
import os
from download import download
import pandas as pd
from matplotlib import pyplot as plt

# %matplotlib inline

url_2 = "https://raw.githubusercontent.com/lukes/ISO-3166-Countries-with-Regional-Codes/master/all/all.csv"
regional_file_name = "regions.csv"

url = "http://vam.wfp.org/sites/data/WFPVAM_FoodPrices_05-12-2017.csv"
file_name = 'WFPVAM_FoodPrices_05-12-2017.csv'

def get_dataset(url, file_name):
    if not os.path.isfile(file_name):
        download(url, file_name)
    
    return pd.read_csv(file_name, encoding='latin-1')

df = get_dataset(url, file_name)

region_df = get_dataset(url_2, regional_file_name)

# %%
# Pre-process
df = pd.read_csv('WFPVAM_FoodPrices_version1.csv')
# region_df.rename(columns={'name': 'adm0_name'}, inplace=True)
# new_regions = region_df.loc[:, ['adm0_name', 'sub-region']]

# df_regions = pd.merge(df, new_regions, on='adm0_name', how='left')

# df = df_regions.copy()

# df['datetime'] = pd.to_datetime(df.mp_year*10000+df.mp_month*100+1, format='%Y%m%d')

# %%
df
# Out:
#           adm0_name  mkt_name               cm_name cur_name pt_name um_name  \
# 0       Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 1       Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 2       Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 3       Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 4       Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 5       Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 6       Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 7       Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 8       Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 9       Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 10      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 11      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 12      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 13      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 14      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 15      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 16      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 17      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 18      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 19      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 20      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 21      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 22      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 23      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 24      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 25      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 26      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 27      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 28      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 29      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# ...             ...       ...                   ...      ...     ...     ...
# 746499  South Sudan     Torit       Oil (vegetable)      SSP  Retail       L
# 746500  South Sudan     Torit       Oil (vegetable)      SSP  Retail       L
# 746501  South Sudan     Torit       Oil (vegetable)      SSP  Retail       L
# 746502  South Sudan     Torit       Oil (vegetable)      SSP  Retail       L
# 746503  South Sudan     Torit       Oil (vegetable)      SSP  Retail       L
# 746504  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746505  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746506  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746507  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746508  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746509  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746510  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746511  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746512  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746513  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746514  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746515  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746516  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746517  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746518  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746519  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746520  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746521  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746522  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746523  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746524  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746525  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746526  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746527  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746528  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
#
#         mp_price     date
# 0        50.0000   2014-1
# 1        50.0000   2014-2
# 2        50.0000   2014-3
# 3        50.0000   2014-4
# 4        50.0000   2014-5
# 5        50.0000   2014-6
# 6        50.0000   2014-7
# 7        50.0000   2014-8
# 8        50.0000   2014-9
# 9        50.0000  2014-10
# 10       50.0000  2014-11
# 11       50.0000  2014-12
# 12       50.0000   2015-1
# 13       50.0000   2015-2
# 14       50.0000   2015-3
# 15       50.0000   2015-6
# 16       50.0000   2015-7
# 17       50.0000   2015-8
# 18       50.0000   2015-9
# 19       56.2500  2015-10
# 20       65.2500  2015-11
# 21       55.5000  2015-12
# 22       55.5000   2016-1
# 23       55.5000   2016-2
# 24       55.5000   2016-3
# 25       50.0000   2016-4
# 26       50.0000   2016-5
# 27       50.0000   2016-6
# 28       50.0000   2016-7
# 29       50.0000   2016-8
# ...          ...      ...
# 746499  250.0000   2017-5
# 746500  244.0000   2017-6
# 746501  240.0000   2017-7
# 746502  240.0000   2017-8
# 746503  235.0000  2017-10
# 746504    9.5000   2014-8
# 746505    9.0000   2014-9
# 746506    9.0000  2014-10
# 746507    8.3333  2014-11
# 746508   10.5000  2014-12
# 746509    8.0000   2015-1
# 746510    8.0000   2015-2
# 746511    7.0000   2015-3
# 746512   10.0000   2015-4
# 746513   41.0000   2016-1
# 746514   57.7500   2016-3
# 746515   37.7500   2016-4
# 746516   72.0000   2016-5
# 746517  100.0000   2016-7
# 746518  120.0000   2016-8
# 746519   73.5000   2016-9
# 746520  110.0000  2016-10
# 746521  132.5000  2016-11
# 746522  151.2500  2016-12
# 746523  200.0000   2017-2
# 746524  236.0000   2017-3
# 746525  250.0000   2017-6
# 746526  308.0000   2017-7
# 746527  343.0000   2017-8
# 746528  283.0000  2017-10
#
# [746529 rows x 8 columns]

# %%
def unique_per_cat(df):
    """
    Dit geeft per colum in de dataset de unique values.
    """
    for col in set(df):
        print(col)
        try:
            print(np.sort(df.eval(col).unique()))
        except:
            print(df.eval(col).unique())
        print(len(df.eval(col).unique()))

unique_per_cat(df)
# Out:
# date
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-f40a788b9327> in unique_per_cat(df)
#       7         try:
# ----> 8             print(np.sort(df.eval(col).unique()))
#       9         except:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    2365         kwargs['resolvers'] = kwargs.get('resolvers', ()) + tuple(resolvers)
# -> 2366         return _eval(expr, inplace=inplace, **kwargs)
#    2367
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     294         eng_inst = eng(parsed_expr)
# --> 295         ret = eng_inst.evaluate()
#     296
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/computation/engines.py in evaluate(self)
#      75         # make sure no names in resolvers and locals/globals clash
# ---> 76         res = self._evaluate()
#      77         return _reconstruct_object(self.result_type, res, self.aligned_axes,
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/computation/engines.py in _evaluate(self)
#     122             _check_ne_builtin_clash(self.expr)
# --> 123             return ne.evaluate(s, local_dict=scope, truediv=truediv)
#     124         except KeyError as e:
#
# /anaconda3/lib/python3.6/site-packages/numexpr/necompiler.py in evaluate(ex, local_dict, global_dict, out, order, casting, **kwargs)
#     806     signature = [(name, getType(arg)) for (name, arg) in
# --> 807                  zip(names, arguments)]
#     808
#
# /anaconda3/lib/python3.6/site-packages/numexpr/necompiler.py in <listcomp>(.0)
#     805     # Create a signature
# --> 806     signature = [(name, getType(arg)) for (name, arg) in
#     807                  zip(names, arguments)]
#
# /anaconda3/lib/python3.6/site-packages/numexpr/necompiler.py in getType(a)
#     703         return bytes
# --> 704     raise ValueError("unknown type %s" % a.dtype.name)
#     705
#
# ValueError: unknown type object
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-f40a788b9327> in <module>()
#      11         print(len(df.eval(col).unique()))
#      12
# ---> 13 unique_per_cat(df)
#
# <ipython-input-60-f40a788b9327> in unique_per_cat(df)
#       8             print(np.sort(df.eval(col).unique()))
#       9         except:
# ---> 10             print(df.eval(col).unique())
#      11         print(len(df.eval(col).unique()))
#      12
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    2364             kwargs['target'] = self
#    2365         kwargs['resolvers'] = kwargs.get('resolvers', ()) + tuple(resolvers)
# -> 2366         return _eval(expr, inplace=inplace, **kwargs)
#    2367
#    2368     def select_dtypes(self, include=None, exclude=None):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     293         eng = _engines[engine]
#     294         eng_inst = eng(parsed_expr)
# --> 295         ret = eng_inst.evaluate()
#     296
#     297         if parsed_expr.assigner is None:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/computation/engines.py in evaluate(self)
#      74
#      75         # make sure no names in resolvers and locals/globals clash
# ---> 76         res = self._evaluate()
#      77         return _reconstruct_object(self.result_type, res, self.aligned_axes,
#      78                                    self.expr.terms.return_type)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/computation/engines.py in _evaluate(self)
#     121             truediv = scope['truediv']
#     122             _check_ne_builtin_clash(self.expr)
# --> 123             return ne.evaluate(s, local_dict=scope, truediv=truediv)
#     124         except KeyError as e:
#     125             # python 3 compat kludge
#
# /anaconda3/lib/python3.6/site-packages/numexpr/necompiler.py in evaluate(ex, local_dict, global_dict, out, order, casting, **kwargs)
#     805     # Create a signature
#     806     signature = [(name, getType(arg)) for (name, arg) in
# --> 807                  zip(names, arguments)]
#     808
#     809     # Look up numexpr if possible.
#
# /anaconda3/lib/python3.6/site-packages/numexpr/necompiler.py in <listcomp>(.0)
#     804
#     805     # Create a signature
# --> 806     signature = [(name, getType(arg)) for (name, arg) in
#     807                  zip(names, arguments)]
#     808
#
# /anaconda3/lib/python3.6/site-packages/numexpr/necompiler.py in getType(a)
#     702     if kind == 'S':
#     703         return bytes
# --> 704     raise ValueError("unknown type %s" % a.dtype.name)
#     705
#     706
#
# ValueError: unknown type object

# %%
# for product in df.cm_name.unique():
#     print(product)
    
for groep, _ in df.groupby([PROD, UNIT]):
    print(groep)
# Out:
# ('Apples', 'KG')
# ('Apples (red)', '500 G')
# ('Apples (red)', 'KG')
# ('Avocados', 'Unit')
# ('Bananas', '500 G')
# ('Bananas', 'KG')
# ('Bananas', 'Pound')
# ('Beans', '100 KG')
# ('Beans', 'KG')
# ('Beans (black)', '45 KG')
# ('Beans (black)', 'MT')
# ('Beans (black)', 'Marmite')
# ('Beans (black)', 'Pound')
# ('Beans (butter)', 'KG')
# ('Beans (catarino)', 'KG')
# ('Beans (dry)', '500 G')
# ('Beans (dry)', '90 KG')
# ('Beans (dry)', 'KG')
# ('Beans (fava, dry)', 'KG')
# ('Beans (green, fresh)', 'KG')
# ('Beans (haricot)', 'KG')
# ('Beans (kidney red)', 'KG')
# ('Beans (kidney white)', 'KG')
# ('Beans (kidney)', 'KG')
# ('Beans (magnum)', 'KG')
# ('Beans (niebe)', '90 KG')
# ('Beans (niebe)', 'KG')
# ('Beans (niebe, white)', 'KG')
# ('Beans (red)', '45 KG')
# ('Beans (red)', 'KG')
# ('Beans (red)', 'MT')
# ('Beans (red)', 'Marmite')
# ('Beans (red, fresh)', 'KG')
# ('Beans (silk red)', '45 KG')
# ('Beans (string)', 'KG')
# ('Beans (sugar) ', 'KG')
# ('Beans (sugar-red)', '500 G')
# ('Beans (white)', 'KG')
# ('Beans(mash)', 'KG')
# ('Beetroots', 'KG')
# ('Blackberry', 'KG')
# ('Bread', '150 G')
# ('Bread', '400 G')
# ('Bread', '500 G')
# ('Bread', 'KG')
# ('Bread', 'Pound')
# ('Bread', 'Unit')
# ('Bread (bakery)', '1.5 KG')
# ('Bread (brown)', 'Loaf')
# ('Bread (common)', 'KG')
# ('Bread (first grade flour)', 'KG')
# ('Bread (high grade flour)', 'KG')
# ('Bread (khoboz)', 'Unit')
# ('Bread (pita)', 'KG')
# ('Bread (rye)', 'Loaf')
# ('Bread (shop)', '1.5 KG')
# ('Bread (wheat)', 'Loaf')
# ('Bread (wheat)', 'Unit')
# ('Broccoli', 'KG')
# ('Buckwheat grits', 'KG')
# ('Bulgur', 'KG')
# ('Butter', 'KG')
# ('Cabbage', '500 G')
# ('Cabbage', 'KG')
# ('Carrots', '500 G')
# ('Carrots', 'KG')
# ('Cashew', '500 G')
# ('Cassava', '3.5 KG')
# ('Cassava', '500 G')
# ('Cassava', '91 KG')
# ('Cassava', 'KG')
# ('Cassava (chikwangue)', 'KG')
# ('Cassava (cossette)', '90 KG')
# ('Cassava (cossette)', 'KG')
# ('Cassava (dry)', '3.5 KG')
# ('Cassava (dry)', 'KG')
# ('Cassava (fresh)', '50 KG')
# ('Cassava (fresh)', 'KG')
# ('Cassava flour', 'KG')
# ('Cassava leaves', 'KG')
# ('Cassava meal', 'KG')
# ('Cassava meal (gari)', 'KG')
# ('Cauliflower', 'KG')
# ('Charcoal', 'Sack')
# ('Cheese', 'KG')
# ('Cheese (dry)', 'KG')
# ('Cheese (dry)', 'Pound')
# ('Cheese (goat)', 'KG')
# ('Cheese (picon)', '160 G')
# ('Cheese (picon)', '168 G')
# ('Cheese (picon)', 'KG')
# ('Cheese (white, boiled)', 'KG')
# ('Chickpeas', 'KG')
# ('Chickpeas (imported)', 'KG')
# ('Chickpeas (local)', 'KG')
# ('Chili (green)', 'KG')
# ('Chili (red)', 'KG')
# ('Cocoa', 'KG')
# ('Cocoa', 'Libra')
# ('Cocoa (powder)', 'KG')
# ('Coffee', 'KG')
# ('Coffee', 'Libra')
# ('Coffee', 'Pound')
# ('Coffee (instant)', '500 G')
# ('Coffee (instant)', '85 G')
# ('Coffee (instant)', 'Unit')
# ('Cornstarch', 'KG')
# ('Cowpeas', 'KG')
# ('Cowpeas (brown)', '100 KG')
# ('Cowpeas (white)', '100 KG')
# ('Cucumbers', 'KG')
# ('Cucumbers (greenhouse)', 'KG')
# ('Curd', 'KG')
# ('Dates', 'KG')
# ('Eggplants', 'KG')
# ('Eggs', '1.8 KG')
# ('Eggs', '10 pcs')
# ('Eggs', '2 KG')
# ('Eggs', '30 pcs')
# ('Eggs', '650 G')
# ('Eggs', 'Dozen')
# ('Eggs', 'KG')
# ('Eggs', 'Unit')
# ('Eggs (imported)', '10 pcs')
# ('Eggs (white, AA)', 'Unit')
# ('Exchange rate', 'USD/LCU')
# ('Exchange rate (unofficial)', 'USD/LCU')
# ('Fat (salo)', 'KG')
# ('Fish (appolo)', 'KG')
# ('Fish (bonga)', '500 G')
# ('Fish (catfish)', 'KG')
# ('Fish (dry)', '500 G')
# ('Fish (dry)', 'KG')
# ('Fish (fresh)', 'KG')
# ('Fish (frozen)', 'KG')
# ('Fish (red snapper)', 'KG')
# ('Fish (salted)', 'KG')
# ('Fish (sardine, canned)', 'KG')
# ('Fish (smoked)', 'KG')
# ('Fish (snake head)', 'KG')
# ('Fish (tilapia)', 'Libra')
# ('Fish (tilapia, farmed)', 'KG')
# ('Fish (tuna, canned)', '185 G')
# ('Fish (tuna, canned)', 'KG')
# ('Fonio', 'KG')
# ('Fuel (diesel)', '500 ML')
# ('Fuel (diesel)', 'Gallon')
# ('Fuel (diesel)', 'KG')
# ('Fuel (diesel)', 'L')
# ('Fuel (gas)', '10 KG')
# ('Fuel (gas)', '12 KG')
# ('Fuel (gas)', '18 KG')
# ('Fuel (kerosene)', '1.5 L')
# ('Fuel (kerosene)', '500 ML')
# ('Fuel (kerosene)', 'L')
# ('Fuel (petrol-gasoline)', '500 ML')
# ('Fuel (petrol-gasoline)', 'Gallon')
# ('Fuel (petrol-gasoline)', 'L')
# ('Gari (white)', '100 KG')
# ('Gari (white)', 'KG')
# ('Gari (yellow)', '100 KG')
# ('Gari (yellow)', 'KG')
# ('Garlic', '500 G')
# ('Garlic', 'KG')
# ('Garlic (small)', 'KG')
# ('Ghee (artificial)', 'KG')
# ('Ghee (natural)', 'KG')
# ('Ghee (vanaspati)', 'KG')
# ('Groundnuts (Mix)', 'KG')
# ('Groundnuts (large, shelled)', 'KG')
# ('Groundnuts (paste)', 'KG')
# ('Groundnuts (shelled)', '100 KG')
# ('Groundnuts (shelled)', '500 G')
# ('Groundnuts (shelled)', '90 KG')
# ('Groundnuts (shelled)', 'KG')
# ('Groundnuts (small, shelled)', 'KG')
# ('Groundnuts (unshelled)', '500 G')
# ('Guava', 'KG')
# ('Labaneh', '500 G')
# ('Lentils', 'KG')
# ('Lentils (imported)', 'KG')
# ('Lentils (masur)', 'KG')
# ('Lentils (moong)', 'KG')
# ('Lentils (urad)', 'KG')
# ('Lettuce', 'Head')
# ('Livestock (Goat)', 'Head')
# ('Livestock (Goat)', 'Unit')
# ('Livestock (Sheep)', 'Head')
# ('Livestock (Sheep)', 'Unit')
# ('Livestock (goat, medium-sized castrated male)', 'Unit')
# ('Livestock (hen)', 'Unit')
# ('Livestock (pig)', 'Unit')
# ('Livestock (sheep, medium-sized castrated male)', 'Unit')
# ('Livestock (sheep, one-year-old alive female)', 'Unit')
# ('Livestock (sheep, two-year-old male)', 'Head')
# ('Livestock (sheep, two-year-old male)', 'Unit')
# ('Maize', '100 KG')
# ('Maize', '500 G')
# ('Maize', '90 KG')
# ('Maize', 'KG')
# ('Maize (imported)', 'KG')
# ('Maize (local)', '500 G')
# ('Maize (local)', 'KG')
# ('Maize (white)', '100 KG')
# ('Maize (white)', '3.5 KG')
# ('Maize (white)', '45 KG')
# ('Maize (white)', '50 KG')
# ('Maize (white)', '90 KG')
# ('Maize (white)', 'KG')
# ('Maize (white)', 'MT')
# ('Maize (yellow)', '100 KG')
# ('Maize (yellow)', '45 KG')
# ('Maize (yellow)', '50 KG')
# ('Maize (yellow)', 'KG')
# ('Maize (yellow)', 'MT')
# ('Maize flour', '500 G')
# ('Maize flour', 'KG')
# ('Maize flour (imported)', '750 G')
# ('Maize flour (imported)', 'KG')
# ('Maize flour (white)', 'MT')
# ('Maize meal', '12.5 KG')
# ('Maize meal', 'KG')
# ('Maize meal (local)', 'Marmite')
# ('Maize meal (white, breakfast)', 'KG')
# ('Maize meal (white, first grade)', 'KG')
# ('Maize meal (white, roller)', 'KG')
# ('Maize meal (white, with bran)', 'KG')
# ('Maize meal (white, without bran) ', 'KG')
# ('Mangoes', 'KG')
# ('Meat (beef)', '500 G')
# ('Meat (beef)', 'KG')
# ('Meat (beef, canned)', '200 G')
# ('Meat (beef, chops with bones)', 'KG')
# ('Meat (beef, chops with bones)', 'Pound')
# ('Meat (beef, first quality)', 'KG')
# ('Meat (beef, minced)', 'KG')
# ('Meat (beef, second quality)', 'KG')
# ('Meat (beef, without bones)', 'KG')
# ('Meat (buffalo, first quality)', 'KG')
# ('Meat (buffalo, second quality)', 'KG')
# ('Meat (chicken)', '500 G')
# ('Meat (chicken)', 'KG')
# ('Meat (chicken)', 'Pound')
# ('Meat (chicken, broiler)', 'KG')
# ('Meat (chicken, frozen)', 'KG')
# ('Meat (chicken, imported)', 'KG')
# ('Meat (chicken, whole)', 'KG')
# ('Meat (goat)', 'KG')
# ('Meat (goat, with bones)', 'KG')
# ('Meat (lamb)', 'KG')
# ('Meat (mixed, sausage)', 'KG')
# ('Meat (mutton)', '500 G')
# ('Meat (mutton)', 'KG')
# ('Meat (pork)', 'KG')
# ('Meat (pork, first quality)', 'KG')
# ('Meat (pork, second quality)', 'KG')
# ('Meat (pork, with fat)', 'KG')
# ('Meat (veal)', 'KG')
# ('Milk', '500 G')
# ('Milk', 'L')
# ('Milk (condensed)', '385 G')
# ('Milk (cow, pasteurized)', '500 ML')
# ('Milk (non-pasteurized)', 'L')
# ('Milk (pasteurized)', '380 G')
# ('Milk (pasteurized)', '500 ML')
# ('Milk (pasteurized)', 'KG')
# ('Milk (pasteurized)', 'L')
# ('Milk (powder)', '1.8 KG')
# ('Milk (powder)', 'KG')
# ('Milk (powder)', 'Pound')
# ('Milk (powder)', 'Unit')
# ('Milk (powder, infant formula)', 'KG')
# ('Millet', '100 KG')
# ('Millet', '3.5 KG')
# ('Millet', '500 G')
# ('Millet', 'KG')
# ('Millet (white)', '3.5 KG')
# ('Noodles (short)', 'Cuartilla')
# ('Noodles (short)', 'KG')
# ('Noodles (short)', 'Pound')
# ('Oil', 'L')
# ('Oil (cooking)', 'L')
# ('Oil (cotton)', 'L')
# ('Oil (groundnut)', '500 ML')
# ('Oil (groundnut)', 'KG')
# ('Oil (groundnut)', 'L')
# ('Oil (maize)', '3 L')
# ('Oil (maize)', 'L')
# ('Oil (mixed)', 'L')
# ('Oil (mixed, imported)', 'L')
# ('Oil (mustard)', 'KG')
# ('Oil (olive)', 'KG')
# ('Oil (olive)', 'L')
# ('Oil (palm)', '100 KG')
# ('Oil (palm)', '500 ML')
# ('Oil (palm)', 'Gallon')
# ('Oil (palm)', 'KG')
# ('Oil (palm)', 'L')
# ('Oil (soybean)', 'KG')
# ('Oil (soybean)', 'L')
# ('Oil (sunflower)', '5 L')
# ('Oil (sunflower)', '750 ML')
# ('Oil (sunflower)', 'KG')
# ('Oil (sunflower)', 'L')
# ('Oil (vegetable)', '500 ML')
# ('Oil (vegetable)', '750 ML')
# ('Oil (vegetable)', 'KG')
# ('Oil (vegetable)', 'L')
# ('Oil (vegetable, imported)', 'Gallon')
# ('Oil (vegetable, imported)', 'L')
# ('Oil (vegetable, local)', 'L')
# ('Onions', '500 G')
# ('Onions', '90 KG')
# ('Onions', 'KG')
# ('Onions', 'Pound')
# ('Onions (red)', 'KG')
# ('Onions (white)', 'KG')
# ('Oranges (big size)', '500 G')
# ('Oranges (big size)', 'KG')
# ('Papaya', 'KG')
# ('Parsley', 'Packet')
# ('Passion fruit', 'KG')
# ('Pasta', '350 G')
# ('Pasta', 'KG')
# ('Pasta', 'Pound')
# ('Peanut', 'KG')
# ('Peas (dry)', 'KG')
# ('Peas (fresh)', 'KG')
# ('Peas (green, dry)', '500 G')
# ('Peas (green, dry)', 'KG')
# ('Peas (split, dry)', '500 G')
# ('Peas (yellow)', '90 KG')
# ('Peas (yellow)', 'KG')
# ('Peas (yellow, split)', 'KG')
# ('Peppers (green)', 'KG')
# ('Plantains', 'KG')
# ('Plantains', 'Pound')
# ('Plantains (apentu)', 'Bunch')
# ('Potatoes', 'KG')
# ('Potatoes', 'Pound')
# ('Potatoes (Dutch)', '11.5 KG')
# ('Potatoes (Dutch)', 'Cuartilla')
# ('Potatoes (Dutch)', 'Pound')
# ('Potatoes (Irish)', '50 KG')
# ('Potatoes (Irish)', '500 G')
# ('Potatoes (Irish)', 'KG')
# ('Potatoes (Irish, imilla)', '11.5 KG')
# ('Potatoes (Irish, imilla)', 'Cuartilla')
# ('Potatoes (Irish, imilla)', 'KG')
# ('Potatoes (Irish, imilla)', 'Pound')
# ('Potatoes (black)', 'KG')
# ('Potatoes (unica)', 'KG')
# ('Poultry', 'KG')
# ('Pulses', 'KG')
# ('Pumpkin', 'KG')
# ('Rice', '100 KG')
# ('Rice', '45 KG')
# ('Rice', 'KG')
# ('Rice (basmati, broken)', '500 G')
# ('Rice (basmati, broken)', 'KG')
# ('Rice (carolina 2da)', 'KG')
# ('Rice (coarse)', 'KG')
# ('Rice (denikassia, imported)', 'KG')
# ('Rice (estaquilla)', 'Cuartilla')
# ('Rice (estaquilla)', 'KG')
# ('Rice (estaquilla)', 'Pound')
# ('Rice (glutinous, first quality)', 'KG')
# ('Rice (glutinous, second quality)', 'KG')
# ('Rice (glutinous, unmilled)', 'KG')
# ('Rice (good quality)', 'Cuartilla')
# ('Rice (good quality)', 'KG')
# ('Rice (high quality)', 'KG')
# ('Rice (high quality, local)', 'KG')
# ('Rice (imported)', '50 KG')
# ('Rice (imported)', 'KG')
# ('Rice (imported, Egyptian)', 'KG')
# ('Rice (imported, Indian)', 'KG')
# ('Rice (imported, Tanzanian)', 'KG')
# ('Rice (local)', '100 KG')
# ('Rice (local)', '50 KG')
# ('Rice (local)', '90 KG')
# ('Rice (local)', 'KG')
# ('Rice (local)', 'Marmite')
# ('Rice (long grain)', 'KG')
# ('Rice (long grain, imported)', '500 G')
# ('Rice (low quality)', 'KG')
# ('Rice (low quality, local)', 'KG')
# ('Rice (medium grain)', 'KG')
# ('Rice (medium grain, imported)', '500 G')
# ('Rice (milled 80-20)', 'MT')
# ('Rice (mixed, low quality)', 'KG')
# ('Rice (ordinary, first quality)', '45 KG')
# ('Rice (ordinary, first quality)', 'KG')
# ('Rice (ordinary, second quality)', '45 KG')
# ('Rice (ordinary, second quality)', 'KG')
# ('Rice (ordinary, second quality)', 'Pound')
# ('Rice (ordinary, unmilled)', 'KG')
# ('Rice (paddy)', 'KG')
# ('Rice (paddy)', 'MT')
# ('Rice (paddy, long grain, local)', '500 G')
# ('Rice (red nadu)', 'KG')
# ('Rice (regular, milled)', 'KG')
# ('Rice (small grain, imported)', '25 KG')
# ('Rice (small grain, imported)', '500 G')
# ('Rice (tchako)', 'Marmite')
# ('Rice (white)', 'KG')
# ('Rice (white)', 'MT')
# ('Rice (white, imported)', '50 KG')
# ('Salt', '115 G')
# ('Salt', '500 G')
# ('Salt', 'KG')
# ('Salt (iodised)', 'KG')
# ('Sesame', '3.5 KG')
# ('Sesame', '90 KG')
# ('Sorghum', '100 KG')
# ('Sorghum', '3 KG')
# ('Sorghum', '500 G')
# ('Sorghum', '90 KG')
# ('Sorghum', 'KG')
# ('Sorghum', 'Marmite')
# ('Sorghum (berbere)', 'KG')
# ('Sorghum (brown)', '100 KG')
# ('Sorghum (food aid)', '3 KG')
# ('Sorghum (red)', '90 KG')
# ('Sorghum (red)', 'KG')
# ('Sorghum (taghalit)', 'KG')
# ('Sorghum (white)', '100 KG')
# ('Sorghum (white)', '3.5 KG')
# ('Sorghum (white)', '90 KG')
# ('Sorghum (white)', 'KG')
# ('Sorghum (white)', 'MT')
# ('Sorghum flour', 'KG')
# ('Sour cream', 'L')
# ('Soybeans', '90 KG')
# ('Soybeans', 'KG')
# ('Spinach', 'KG')
# ('Sugar', '500 G')
# ('Sugar', 'KG')
# ('Sugar', 'Pound')
# ('Sugar (brown)', 'KG')
# ('Sugar (brown, loaf)', 'KG')
# ('Sugar (brown, local)', 'KG')
# ('Sugar (jaggery/gur)', 'KG')
# ('Sugar (white)', 'Marmite')
# ('Sweet potatoes', '500 G')
# ('Sweet potatoes', 'KG')
# ('Tamarillos/tree tomatoes', 'KG')
# ('Tea', 'KG')
# ('Tea', 'Unit')
# ('Tea (black)', 'KG')
# ('Tea (green)', 'KG')
# ('Tea (green)', 'Unit')
# ('Tomatoes', '500 G')
# ('Tomatoes', 'KG')
# ('Tomatoes', 'Pound')
# ('Tomatoes (paste)', 'KG')
# ('Tortilla (maize)', 'Pound')
# ('Transport (public)', 'Course')
# ('Wage (non-qualified labour)', 'Day')
# ('Wage (non-qualified labour, non-agricultural)', 'Day')
# ('Wage (non-qualified labour, non-agricultural)', 'Month')
# ('Wage (qualified labour)', 'Day')
# ('Water (drinking)', 'Cubic meter')
# ('Wheat', '100 KG')
# ('Wheat', '3 KG')
# ('Wheat', 'KG')
# ('Wheat flour', '12.5 KG')
# ('Wheat flour', '5 KG')
# ('Wheat flour', '50 KG')
# ('Wheat flour', 'KG')
# ('Wheat flour (first grade)', 'KG')
# ('Wheat flour (high quality)', 'KG')
# ('Wheat flour (imported)', 'Marmite')
# ('Wheat flour (local)', 'KG')
# ('Wheat flour (locally processed)', 'KG')
# ('Yam', '100 KG')
# ('Yam', '100 Tubers')
# ('Yam', 'KG')
# ('Yam (Abuja)', '100 KG')
# ('Yam (Abuja)', 'KG')
# ('Yam (florido)', 'KG')
# ('Yogurt', '500 G')
# ('Yogurt', 'KG')
# ('Zucchini', 'KG')

# %%
NON_FOOD = [
    'Wage (non-qualified labour)',
    'Wage (non-qualified labour, non-agricultural)',
    'Wage (non-qualified labour, non-agricultural)',
    'Wage (qualified labour)', 
    'Exchange rate',
    'Exchange rate (unofficial)',
    'Transport (public)', 
    ]

#returns all products that are edible
def without_non_food(dataframe):
    return df[~df.cm_name.isin(NON_FOOD)]



df2 = without_non_food(df)
df2
# Out:
#           adm0_name  mkt_name               cm_name cur_name pt_name um_name  \
# 0       Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 1       Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 2       Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 3       Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 4       Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 5       Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 6       Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 7       Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 8       Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 9       Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 10      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 11      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 12      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 13      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 14      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 15      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 16      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 17      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 18      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 19      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 20      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 21      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 22      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 23      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 24      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 25      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 26      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 27      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 28      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# 29      Afghanistan  Fayzabad                 Bread      AFN  Retail      KG
# ...             ...       ...                   ...      ...     ...     ...
# 746499  South Sudan     Torit       Oil (vegetable)      SSP  Retail       L
# 746500  South Sudan     Torit       Oil (vegetable)      SSP  Retail       L
# 746501  South Sudan     Torit       Oil (vegetable)      SSP  Retail       L
# 746502  South Sudan     Torit       Oil (vegetable)      SSP  Retail       L
# 746503  South Sudan     Torit       Oil (vegetable)      SSP  Retail       L
# 746504  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746505  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746506  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746507  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746508  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746509  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746510  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746511  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746512  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746513  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746514  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746515  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746516  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746517  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746518  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746519  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746520  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746521  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746522  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746523  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746524  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746525  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746526  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746527  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
# 746528  South Sudan     Torit  Groundnuts (shelled)      SSP  Retail      KG
#
#         mp_price     date
# 0        50.0000   2014-1
# 1        50.0000   2014-2
# 2        50.0000   2014-3
# 3        50.0000   2014-4
# 4        50.0000   2014-5
# 5        50.0000   2014-6
# 6        50.0000   2014-7
# 7        50.0000   2014-8
# 8        50.0000   2014-9
# 9        50.0000  2014-10
# 10       50.0000  2014-11
# 11       50.0000  2014-12
# 12       50.0000   2015-1
# 13       50.0000   2015-2
# 14       50.0000   2015-3
# 15       50.0000   2015-6
# 16       50.0000   2015-7
# 17       50.0000   2015-8
# 18       50.0000   2015-9
# 19       56.2500  2015-10
# 20       65.2500  2015-11
# 21       55.5000  2015-12
# 22       55.5000   2016-1
# 23       55.5000   2016-2
# 24       55.5000   2016-3
# 25       50.0000   2016-4
# 26       50.0000   2016-5
# 27       50.0000   2016-6
# 28       50.0000   2016-7
# 29       50.0000   2016-8
# ...          ...      ...
# 746499  250.0000   2017-5
# 746500  244.0000   2017-6
# 746501  240.0000   2017-7
# 746502  240.0000   2017-8
# 746503  235.0000  2017-10
# 746504    9.5000   2014-8
# 746505    9.0000   2014-9
# 746506    9.0000  2014-10
# 746507    8.3333  2014-11
# 746508   10.5000  2014-12
# 746509    8.0000   2015-1
# 746510    8.0000   2015-2
# 746511    7.0000   2015-3
# 746512   10.0000   2015-4
# 746513   41.0000   2016-1
# 746514   57.7500   2016-3
# 746515   37.7500   2016-4
# 746516   72.0000   2016-5
# 746517  100.0000   2016-7
# 746518  120.0000   2016-8
# 746519   73.5000   2016-9
# 746520  110.0000  2016-10
# 746521  132.5000  2016-11
# 746522  151.2500  2016-12
# 746523  200.0000   2017-2
# 746524  236.0000   2017-3
# 746525  250.0000   2017-6
# 746526  308.0000   2017-7
# 746527  343.0000   2017-8
# 746528  283.0000  2017-10
#
# [737342 rows x 8 columns]

# %%
def split_df(df):
    # returnt een dataframe met alle rijen die national average bevatten 
    return df.loc[df['mkt_name'] == 'National Average']
    # returnt een dataframe alleen gaat over de steden en de national averages verwijderd
    return df_country_city = df.loc[df['mkt_name'] != 'National Average']
# Out:
#           adm0_name          mkt_name                     cm_name cur_name  \
# 10354       Armenia  National Average               Fuel (diesel)      AMD
# 10355       Armenia  National Average               Fuel (diesel)      AMD
# 10356       Armenia  National Average               Fuel (diesel)      AMD
# 10357       Armenia  National Average               Fuel (diesel)      AMD
# 10358       Armenia  National Average               Fuel (diesel)      AMD
# 10359       Armenia  National Average               Fuel (diesel)      AMD
# 10360       Armenia  National Average               Fuel (diesel)      AMD
# 10361       Armenia  National Average               Fuel (diesel)      AMD
# 10362       Armenia  National Average               Fuel (diesel)      AMD
# 10363       Armenia  National Average               Fuel (diesel)      AMD
# 10364       Armenia  National Average               Fuel (diesel)      AMD
# 10365       Armenia  National Average               Fuel (diesel)      AMD
# 10366       Armenia  National Average               Fuel (diesel)      AMD
# 10367       Armenia  National Average               Fuel (diesel)      AMD
# 10368       Armenia  National Average               Fuel (diesel)      AMD
# 10369       Armenia  National Average               Fuel (diesel)      AMD
# 10370       Armenia  National Average               Fuel (diesel)      AMD
# 10371       Armenia  National Average               Fuel (diesel)      AMD
# 10372       Armenia  National Average               Fuel (diesel)      AMD
# 10373       Armenia  National Average               Fuel (diesel)      AMD
# 10374       Armenia  National Average               Fuel (diesel)      AMD
# 10375       Armenia  National Average               Fuel (diesel)      AMD
# 10376       Armenia  National Average               Fuel (diesel)      AMD
# 10377       Armenia  National Average               Fuel (diesel)      AMD
# 10378       Armenia  National Average               Fuel (diesel)      AMD
# 10379       Armenia  National Average               Fuel (diesel)      AMD
# 10380       Armenia  National Average               Fuel (diesel)      AMD
# 10381       Armenia  National Average               Fuel (diesel)      AMD
# 10382       Armenia  National Average               Fuel (diesel)      AMD
# 10383       Armenia  National Average               Fuel (diesel)      AMD
# ...             ...               ...                         ...      ...
# 741680  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741681  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741682  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741683  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741684  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741685  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741686  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741687  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741688  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741689  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741690  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741691  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741692  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741693  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741694  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741695  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741696  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741697  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741698  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741699  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741700  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741701  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741702  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741703  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741704  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741705  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741706  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741707  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741708  South Sudan  National Average  Exchange rate (unofficial)      SSP
# 741709  South Sudan  National Average  Exchange rate (unofficial)      SSP
#
#        pt_name  um_name  mp_price     date
# 10354   Retail        L  100.0000   1996-1
# 10355   Retail        L  100.0000   1996-2
# 10356   Retail        L  110.0000   1996-3
# 10357   Retail        L  100.0000   1996-4
# 10358   Retail        L  110.0000   1996-5
# 10359   Retail        L  115.0000   1996-6
# 10360   Retail        L  120.0000   1996-7
# 10361   Retail        L  120.0000   1996-8
# 10362   Retail        L  120.0000   1996-9
# 10363   Retail        L  150.0000  1996-10
# 10364   Retail        L  160.0000  1996-11
# 10365   Retail        L  160.0000  1996-12
# 10366   Retail        L  160.0000   1997-1
# 10367   Retail        L  140.0000   1997-2
# 10368   Retail        L  135.0000   1997-3
# 10369   Retail        L  150.0000   1997-4
# 10370   Retail        L  150.0000   1997-5
# 10371   Retail        L  150.0000   1997-6
# 10372   Retail        L  150.0000   1997-7
# 10373   Retail        L  170.0000   1997-8
# 10374   Retail        L  160.0000   1997-9
# 10375   Retail        L  170.0000  1997-10
# 10376   Retail        L  170.0000  1997-11
# 10377   Retail        L  170.0000  1997-12
# 10378   Retail        L  170.0000   1998-1
# 10379   Retail        L  170.0000   1998-2
# 10380   Retail        L  170.0000   1998-3
# 10381   Retail        L  170.0000   1998-4
# 10382   Retail        L  170.0000   1998-5
# 10383   Retail        L  170.0000   1998-6
# ...        ...      ...       ...      ...
# 741680  Retail  USD/LCU    3.9750   2014-3
# 741681  Retail  USD/LCU    3.8750   2014-4
# 741682  Retail  USD/LCU    4.2250   2014-5
# 741683  Retail  USD/LCU    4.4500   2014-6
# 741684  Retail  USD/LCU    4.6880   2014-7
# 741685  Retail  USD/LCU    4.6630   2014-8
# 741686  Retail  USD/LCU    4.6880   2014-9
# 741687  Retail  USD/LCU    5.3050  2014-10
# 741688  Retail  USD/LCU    5.7250  2014-11
# 741689  Retail  USD/LCU    5.8750  2014-12
# 741690  Retail  USD/LCU    6.2750   2015-1
# 741691  Retail  USD/LCU    6.2606   2015-2
# 741692  Retail  USD/LCU    6.7000   2015-3
# 741693  Retail  USD/LCU    8.8000   2015-4
# 741694  Retail  USD/LCU   10.2000   2015-5
# 741695  Retail  USD/LCU   10.5000   2015-6
# 741696  Retail  USD/LCU   12.2500   2015-7
# 741697  Retail  USD/LCU   14.7200   2015-8
# 741698  Retail  USD/LCU   16.3500   2015-9
# 741699  Retail  USD/LCU   17.0800  2015-10
# 741700  Retail  USD/LCU   18.0000  2015-11
# 741701  Retail  USD/LCU   18.5000  2015-12
# 741702  Retail  USD/LCU   20.9800   2016-1
# 741703  Retail  USD/LCU   30.5000   2016-2
# 741704  Retail  USD/LCU   35.0000   2016-3
# 741705  Retail  USD/LCU   37.0000   2016-4
# 741706  Retail  USD/LCU   38.0000   2016-5
# 741707  Retail  USD/LCU   48.0000   2016-6
# 741708  Retail  USD/LCU   65.0000   2016-7
# 741709  Retail  USD/LCU   67.0000   2016-8
#
# [12269 rows x 8 columns]
# Empty DataFrame
# Columns: [adm0_name, mkt_name, cm_name, cur_name, pt_name, um_name, mp_price, date]
# Index: []
